# %%
# %sql
-- Loadstar Trucking - Unity Catalog setup
-- Creates catalog + schemas for bronze/silver/gold

# %%
# %sql
USE CATALOG workspace;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS loadstar_bronze;
CREATE SCHEMA IF NOT EXISTS loadstar_silver;
CREATE SCHEMA IF NOT EXISTS loadstar_gold;
