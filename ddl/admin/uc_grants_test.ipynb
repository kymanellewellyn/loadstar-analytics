# %%
# %sql
use catalog workspace;

select current_catalog() as catalog;

# %%
# %sql
create table if not exists workspace.loadstar_gold._grants_test_gold (
  id int,
  note string
) using delta;

insert into workspace.loadstar_gold._grants_test_gold values (1, 'gold is readable');

# %%
# %sql
-- Try the most common “everyone” principal
GRANT SELECT ON TABLE workspace.loadstar_gold._grants_test_gold TO `account users`;

# %%
# %sql

grant select on table loadstar_gold._grants_test_gold to `account users`;

# %%
# %sql
show grants on table workspace.loadstar_gold._grants_test_gold;

# %%
# %sql
REVOKE SELECT
ON TABLE workspace.loadstar_gold._grants_test_gold
FROM `account users`;

# %%
# %sql
DROP TABLE IF EXISTS workspace.loadstar_gold._grants_test_gold;
