# %%
# UC Volume base
BASE = "/Volumes/workspace/loadstar_bronze/loadstar_files"

# %%
paths = [
    # Maintenance landing + reference + checkpoints
    f"{BASE}/landing/maintenance/events_inbox",
    f"{BASE}/landing/maintenance/reference",
    f"{BASE}/checkpoints/maintenance/bronze_truck_events_raw",
    f"{BASE}/checkpoints/maintenance/silver_truck_events_clean",

    # Transport landing + reference + checkpoints (for later)
    f"{BASE}/landing/transport/snapshots",
    f"{BASE}/landing/transport/reference",
    f"{BASE}/checkpoints/transport/bronze_transport_raw",
    f"{BASE}/checkpoints/transport/silver_transport_clean",
]

# %%
for p in paths:
    dbutils.fs.mkdirs(p)
print("✅ Created UC volume folders:")

# %%
for p in paths:
    print(" -", p)

print("\n✅ Listing BASE:")
display(dbutils.fs.ls(BASE))
