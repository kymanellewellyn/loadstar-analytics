# %%
from src.common.config import CATALOG
from src.common.paths import get_domain_config, get_volume_path

domain = "maintenance"
domain_config = get_domain_config(domain)

raw_schema = domain_config["raw_schema"]
raw_volume = domain_config["raw_volume"]

spark.sql(f"CREATE VOLUME IF NOT EXISTS {CATALOG}.{raw_schema}.{raw_volume}")

print("Volume created:")
print(f"{CATALOG}.{raw_schema}.{raw_volume}")

print("Volume base path:")
print(get_volume_path(domain))
